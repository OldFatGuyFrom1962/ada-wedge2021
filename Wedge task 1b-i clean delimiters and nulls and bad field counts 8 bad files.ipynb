# %% [markdown]
# # This is a test of just one of the zip files where we our concatenation of 3 elements into 1 are specific to a file and a record-index - passes!

# %%
import os

# %%
zip_files = os.listdir("DATA/")

# %%
from zipfile import ZipFile

# %%
import csv

# %%
from timeit import default_timer as timer
start = timer()

# OPTION:  1:42:40m - cheesy approach
for zip_file in zip_files :
    
    with ZipFile("DATA/" + zip_file, 'r') as my_zip_file :
    
        files_inside = my_zip_file.namelist()
        for zipped_file in files_inside :
            sniffer = csv.Sniffer()
            
            #print(zipped_file)
            
            with my_zip_file.open(zipped_file, 'r') as input_file :
                for idx, line in enumerate(input_file) :
                    
                    file_has_header = False
                    
                    dialect = sniffer.sniff(line.decode("utf-8"))
                    line = line.decode("utf-8").strip().split(dialect.delimiter)
                    line = [piece.replace('"','') for piece in line]
# Craig's new line...                    
                    line = [Null.replace('NULL','') for Null in line]
# 201511 has "\\N"
                    line = [DblBk_N.replace('\\N','') for DblBk_N in line]
                            
                    if idx == 0 :
                        if 'datetime' in line[0] :
                            file_has_header = True
                    if file_has_header and idx == 0 :
                        pass
                    else :
                        number = len(line)
                        if number != 50 :
                            print(zipped_file)
                            print(number)
                            print(idx)
                            print(line)

end = timer()
print(end - start)
# Out:
# transArchive_201207_201209.csv
# 52
# 326345
# ['2012-07-11 13:17:56', '700', '700', '117', '0000000003986', 'Fruit', ' Granola', ' and Yogurt', 'I', ' ', ' ', '8', '2', '0', '0.0000', '80.0000', '160.0000', '80.0000', '0.0000', '1', '0', '0', '0', '0.0000', '0.0000', '0', '0', '0', '0.00000000', '2', '0', '2', '0.0000', '0', '0', ' ', '0', '1', '0', '0', '', '0', '', '1', '0', ' ', '0', '20700', '512', '0', '0', '2']
# transArchive_201301_201303.csv
# 52
# 1327813
# ['2013-02-11 15:25:20', '700', '700', '217', '0000000003986', 'Fruit', ' Granola', ' and Yogurt', 'I', ' ', ' ', '8', '1', '0', '0.0000', '60.0000', '60.0000', '60.0000', '0.0000', '1', '0', '0', '0', '0.0000', '0.0000', '0', '0', '0', '0.00000000', '1', '0', '1', '0.0000', '0', '0', ' ', '0', '1', '0', '0', '', '0', '', '1', '0', ' ', '0', '3', '512', '0', '0', '2']
# transArchive_201304_201306.csv
# 52
# 255261
# ['2013-04-08 15:17:07', '700', '700', '375', '0000000003986', 'Fruit', ' Granola', ' and Yogurt', 'I', ' ', ' ', '8', '1', '0', '0.0000', '80.0000', '80.0000', '80.0000', '0.0000', '1', '0', '0', '0', '0.0000', '0.0000', '0', '0', '0', '0.00000000', '1', '0', '1', '0.0000', '0', '0', ' ', '0', '1', '0', '0', '', '0', '', '1', '0', ' ', '0', '3', '512', '0', '0', '2']
# transArchive_201304_201306.csv
# 52
# 255487
# ['2013-04-08 15:23:52', '700', '700', '376', '0000000003986', 'Fruit', ' Granola', ' and Yogurt', 'I', ' ', ' ', '8', '1', '0', '0.0000', '60.0000', '60.0000', '60.0000', '0.0000', '1', '0', '0', '0', '0.0000', '0.0000',